# %% [markdown]
# # Evaluation verification

# %% [markdown]
# The purpose of this notebook is to show that the code used for evaluation is the same as the one used in the original CCMCT and CMC dataset.

# %% [markdown]
# ## CCMCT dataset
# ### Download prediction result from the baseline git
#
# We used the prediction result of the detection stage of the ODAEL variant of the CCMCT dataset as an example.

# %%
# !wget -P ./ https://github.com/DeepPathology/MITOS_WSI_CCMCT/raw/master/results/RetinaNet-ODAEL-export.pth-CCMCT_ODAEL-inference_results_boxes.p.bz2
# Out:
# 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DeepPathology/MITOS_WSI_CCMCT/master/results/RetinaNet-ODAEL-export.pth-CCMCT_ODAEL-inference_results_boxes.p.bz2 [following]
# --2022-07-18 11:31:00--  https://raw.githubusercontent.com/DeepPathology/MITOS_WSI_CCMCT/master/results/RetinaNet-ODAEL-export.pth-CCMCT_ODAEL-inference_results_boxes.p.bz2
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11145255 (11M) [application/octet-stream]
# Saving to: ‘./RetinaNet-ODAEL-export.pth-CCMCT_ODAEL-inference_results_boxes.p.bz2.5’
#
# RetinaNet-ODAEL-exp 100%[===================>]  10.63M  11.0MB/s    in 1.0s
#
# 2022-07-18 11:31:01 (11.0 MB/s) - ‘./RetinaNet-ODAEL-export.pth-CCMCT_ODAEL-inference_results_boxes.p.bz2.5’ saved [11145255/11145255]

# %% [markdown]
# ### Decompress .p.bz2 file and format the output

# %%
import bz2
import pickle
import numpy as np


filepath = './RetinaNet-ODAEL-export.pth-CCMCT_ODAEL-inference_results_boxes.p.bz2'
zipfile = bz2.BZ2File(filepath) 
data = zipfile.read() 
newfilepath = filepath[:-4]
open(newfilepath, 'wb').write(data)
pred = pickle.load(open(newfilepath, 'rb'))
template = pickle.load(open('../detection/mmdetection/data/database/CCMCT_label.pkl', 'rb'))

for i in pred: 
    template[i]['pred_bbox'] = []
    bboxs = []
    for j in pred[i]:
        xmin, ymin, xmax, ymax, cls, conf = j
        bboxs.append(np.array([xmin, ymin, xmax, ymax, conf], dtype = np.float32))
    template[i]['pred_bbox'] = bboxs
pickle.dump(template, open('./CCMCT_baseline_git.pkl', 'wb'))

# %% [markdown]
# ### Evaluate the prediction result
#
# At the threshold of 0.79, the model achieves 0.628, 0.577, and 0.689 F1, precision, and recall, respectively. This match the result shown in https://github.com/DeepPathology/MITOS_WSI_CCMCT/blob/master/Evaluation.ipynb.

# %%
# !python3 tools/eval/calculate_F1.py -ip ./CCMCT_baseline_git.pkl
# Out:
# precision = 0.000, recall = 0.000
# precision = 0.000, recall = 0.000
# precision = 0.000, recall = 0.000
# precision = 0.000, recall = 0.000
# At thresh = 0.96 TP = 80, FN = 22396, FP = 88, F1 = 0.71
# precision = 0.476, recall = 0.004
# At thresh = 0.95 TP = 147, FN = 22329, FP = 144, F1 = 1.29
# precision = 0.505, recall = 0.007
# At thresh = 0.94 TP = 288, FN = 22188, FP = 235, F1 = 2.50
# precision = 0.551, recall = 0.013
# At thresh = 0.93 TP = 528, FN = 21948, FP = 381, F1 = 4.52
# precision = 0.581, recall = 0.023
# At thresh = 0.92 TP = 990, FN = 21486, FP = 596, F1 = 8.23
# precision = 0.624, recall = 0.044
# At thresh = 0.91 TP = 1663, FN = 20813, FP = 871, F1 = 13.30
# precision = 0.656, recall = 0.074
# At thresh = 0.90 TP = 2595, FN = 19881, FP = 1244, F1 = 19.72
# precision = 0.676, recall = 0.115
# At thresh = 0.89 TP = 3856, FN = 18620, FP = 1650, F1 = 27.56
# precision = 0.700, recall = 0.172
# At thresh = 0.88 TP = 5256, FN = 17220, FP = 2209, F1 = 35.11
# precision = 0.704, recall = 0.234
# At thresh = 0.87 TP = 6688, FN = 15788, FP = 2897, F1 = 41.72
# precision = 0.698, recall = 0.298
# At thresh = 0.86 TP = 8192, FN = 14284, FP = 3663, F1 = 47.72
# precision = 0.691, recall = 0.364
# At thresh = 0.85 TP = 9559, FN = 12917, FP = 4495, F1 = 52.34
# precision = 0.680, recall = 0.425
# At thresh = 0.84 TP = 10866, FN = 11610, FP = 5451, F1 = 56.02
# precision = 0.666, recall = 0.483
# At thresh = 0.83 TP = 12016, FN = 10460, FP = 6483, F1 = 58.65
# precision = 0.650, recall = 0.535
# At thresh = 0.82 TP = 13061, FN = 9415, FP = 7606, F1 = 60.55
# precision = 0.632, recall = 0.581
# At thresh = 0.81 TP = 13972, FN = 8504, FP = 8774, F1 = 61.79
# precision = 0.614, recall = 0.622
# At thresh = 0.80 TP = 14751, FN = 7725, FP = 10042, F1 = 62.41
# precision = 0.595, recall = 0.656
# At thresh = 0.79 TP = 15478, FN = 6998, FP = 11324, F1 = 62.82
# precision = 0.577, recall = 0.689
# At thresh = 0.78 TP = 16105, FN = 6371, FP = 12725, F1 = 62.78
# precision = 0.559, recall = 0.717
# At thresh = 0.77 TP = 16669, FN = 5807, FP = 14239, F1 = 62.45
# precision = 0.539, recall = 0.742
# At thresh = 0.76 TP = 17169, FN = 5307, FP = 15792, F1 = 61.94
# precision = 0.521, recall = 0.764
# At thresh = 0.75 TP = 17606, FN = 4870, FP = 17390, F1 = 61.27
# precision = 0.503, recall = 0.783
# At thresh = 0.74 TP = 18016, FN = 4460, FP = 19109, F1 = 60.46
# precision = 0.485, recall = 0.802
# At thresh = 0.73 TP = 18376, FN = 4100, FP = 20758, F1 = 59.65
# precision = 0.470, recall = 0.818
# At thresh = 0.72 TP = 18669, FN = 3807, FP = 22499, F1 = 58.67
# precision = 0.453, recall = 0.831
# At thresh = 0.71 TP = 18946, FN = 3530, FP = 24304, F1 = 57.65
# precision = 0.438, recall = 0.843
# At thresh = 0.70 TP = 19204, FN = 3272, FP = 26261, F1 = 56.53
# precision = 0.422, recall = 0.854
# At thresh = 0.69 TP = 19456, FN = 3020, FP = 28208, F1 = 55.48
# precision = 0.408, recall = 0.866
# At thresh = 0.68 TP = 19695, FN = 2781, FP = 30241, F1 = 54.40
# precision = 0.394, recall = 0.876
# At thresh = 0.67 TP = 19899, FN = 2577, FP = 32389, F1 = 53.23
# precision = 0.381, recall = 0.885
# At thresh = 0.66 TP = 20088, FN = 2388, FP = 34644, F1 = 52.04
# precision = 0.367, recall = 0.894
# At thresh = 0.65 TP = 20244, FN = 2232, FP = 37013, F1 = 50.78
# precision = 0.354, recall = 0.901
# At thresh = 0.64 TP = 20404, FN = 2072, FP = 39389, F1 = 49.60
# precision = 0.341, recall = 0.908
# At thresh = 0.63 TP = 20537, FN = 1939, FP = 41921, F1 = 48.36
# precision = 0.329, recall = 0.914
# At thresh = 0.62 TP = 20644, FN = 1832, FP = 44473, F1 = 47.14
# precision = 0.317, recall = 0.918
# At thresh = 0.61 TP = 20758, FN = 1718, FP = 47252, F1 = 45.88
# precision = 0.305, recall = 0.924
# At thresh = 0.60 TP = 20883, FN = 1593, FP = 50063, F1 = 44.71
# precision = 0.294, recall = 0.929
# At thresh = 0.59 TP = 20976, FN = 1500, FP = 52940, F1 = 43.52
# precision = 0.284, recall = 0.933
# At thresh = 0.58 TP = 21075, FN = 1401, FP = 55953, F1 = 42.36
# precision = 0.274, recall = 0.938
# At thresh = 0.57 TP = 21178, FN = 1298, FP = 59130, F1 = 41.21
# precision = 0.264, recall = 0.942
# At thresh = 0.56 TP = 21270, FN = 1206, FP = 62443, F1 = 40.06
# precision = 0.254, recall = 0.946
# At thresh = 0.55 TP = 21346, FN = 1130, FP = 65827, F1 = 38.94
# precision = 0.245, recall = 0.950
# At thresh = 0.54 TP = 21409, FN = 1067, FP = 69396, F1 = 37.80
# precision = 0.236, recall = 0.953
# At thresh = 0.53 TP = 21481, FN = 995, FP = 73090, F1 = 36.70
# precision = 0.227, recall = 0.956
# At thresh = 0.52 TP = 21540, FN = 936, FP = 76944, F1 = 35.62
# precision = 0.219, recall = 0.958
# At thresh = 0.51 TP = 21586, FN = 890, FP = 80885, F1 = 34.55
# precision = 0.211, recall = 0.960
# At thresh = 0.50 TP = 21636, FN = 840, FP = 85128, F1 = 33.48
# precision = 0.203, recall = 0.963
# At thresh = 0.49 TP = 21679, FN = 797, FP = 89371, F1 = 32.47
# precision = 0.195, recall = 0.965
# At thresh = 0.48 TP = 21718, FN = 758, FP = 93964, F1 = 31.44
# precision = 0.188, recall = 0.966
# At thresh = 0.47 TP = 21756, FN = 720, FP = 98682, F1 = 30.45
# precision = 0.181, recall = 0.968
# At thresh = 0.46 TP = 21793, FN = 683, FP = 103506, F1 = 29.49
# precision = 0.174, recall = 0.970
# At thresh = 0.45 TP = 21827, FN = 649, FP = 108797, F1 = 28.51
# precision = 0.167, recall = 0.971
# At thresh = 0.44 TP = 21868, FN = 608, FP = 114244, F1 = 27.58
# precision = 0.161, recall = 0.973
# At thresh = 0.43 TP = 21901, FN = 575, FP = 119923, F1 = 26.66
# precision = 0.154, recall = 0.974
# At thresh = 0.42 TP = 21936, FN = 540, FP = 125944, F1 = 25.75
# precision = 0.148, recall = 0.976
# At thresh = 0.41 TP = 21968, FN = 508, FP = 132041, F1 = 24.90
# precision = 0.143, recall = 0.977
# At thresh = 0.40 TP = 21997, FN = 479, FP = 138553, F1 = 24.04
# precision = 0.137, recall = 0.979
# At thresh = 0.39 TP = 22025, FN = 451, FP = 145516, F1 = 23.18
# precision = 0.131, recall = 0.980
# At thresh = 0.38 TP = 22048, FN = 428, FP = 152740, F1 = 22.35
# precision = 0.126, recall = 0.981
# At thresh = 0.37 TP = 22075, FN = 401, FP = 160416, F1 = 21.54
# precision = 0.121, recall = 0.982
# At thresh = 0.36 TP = 22094, FN = 382, FP = 168716, F1 = 20.72
# precision = 0.116, recall = 0.983
# At thresh = 0.35 TP = 22109, FN = 367, FP = 177357, F1 = 19.92
# precision = 0.111, recall = 0.984
# At thresh = 0.34 TP = 22126, FN = 350, FP = 186540, F1 = 19.14
# precision = 0.106, recall = 0.984
# At thresh = 0.33 TP = 22155, FN = 321, FP = 196059, F1 = 18.41
# precision = 0.102, recall = 0.986
# At thresh = 0.32 TP = 22172, FN = 304, FP = 206229, F1 = 17.68
# precision = 0.097, recall = 0.986
# At thresh = 0.31 TP = 22185, FN = 291, FP = 217100, F1 = 16.95
# precision = 0.093, recall = 0.987
# At thresh = 0.30 TP = 22202, FN = 274, FP = 228777, F1 = 16.24
# precision = 0.088, recall = 0.988
# At thresh = 0.29 TP = 22202, FN = 274, FP = 228777, F1 = 16.24
# precision = 0.088, recall = 0.988
# At thresh = 0.28 TP = 22202, FN = 274, FP = 228777, F1 = 16.24
# precision = 0.088, recall = 0.988
# At thresh = 0.27 TP = 22202, FN = 274, FP = 228777, F1 = 16.24
# precision = 0.088, recall = 0.988
# At thresh = 0.26 TP = 22202, FN = 274, FP = 228777, F1 = 16.24
# precision = 0.088, recall = 0.988
# At thresh = 0.25 TP = 22202, FN = 274, FP = 228777, F1 = 16.24
# precision = 0.088, recall = 0.988
# At thresh = 0.24 TP = 22202, FN = 274, FP = 228777, F1 = 16.24
# precision = 0.088, recall = 0.988
# At thresh = 0.23 TP = 22202, FN = 274, FP = 228777, F1 = 16.24
# precision = 0.088, recall = 0.988
# At thresh = 0.22 TP = 22202, FN = 274, FP = 228777, F1 = 16.24
# precision = 0.088, recall = 0.988
# At thresh = 0.21 TP = 22202, FN = 274, FP = 228777, F1 = 16.24
# precision = 0.088, recall = 0.988
# At thresh = 0.20 TP = 22202, FN = 274, FP = 228777, F1 = 16.24
# precision = 0.088, recall = 0.988
# At thresh = 0.19 TP = 22202, FN = 274, FP = 228777, F1 = 16.24
# precision = 0.088, recall = 0.988
# At thresh = 0.18 TP = 22202, FN = 274, FP = 228777, F1 = 16.24
# precision = 0.088, recall = 0.988
# At thresh = 0.17 TP = 22202, FN = 274, FP = 228777, F1 = 16.24
# precision = 0.088, recall = 0.988
# At thresh = 0.16 TP = 22202, FN = 274, FP = 228777, F1 = 16.24
# precision = 0.088, recall = 0.988
# At thresh = 0.15 TP = 22202, FN = 274, FP = 228777, F1 = 16.24
# precision = 0.088, recall = 0.988
# At thresh = 0.14 TP = 22202, FN = 274, FP = 228777, F1 = 16.24
# precision = 0.088, recall = 0.988
# At thresh = 0.13 TP = 22202, FN = 274, FP = 228777, F1 = 16.24
# precision = 0.088, recall = 0.988
# At thresh = 0.12 TP = 22202, FN = 274, FP = 228777, F1 = 16.24
# precision = 0.088, recall = 0.988
# At thresh = 0.11 TP = 22202, FN = 274, FP = 228777, F1 = 16.24
# precision = 0.088, recall = 0.988
# At thresh = 0.10 TP = 22202, FN = 274, FP = 228777, F1 = 16.24
# precision = 0.088, recall = 0.988
# At thresh = 0.09 TP = 22202, FN = 274, FP = 228777, F1 = 16.24
# precision = 0.088, recall = 0.988
# At thresh = 0.08 TP = 22202, FN = 274, FP = 228777, F1 = 16.24
# precision = 0.088, recall = 0.988
# At thresh = 0.07 TP = 22202, FN = 274, FP = 228777, F1 = 16.24
# precision = 0.088, recall = 0.988
# At thresh = 0.06 TP = 22202, FN = 274, FP = 228777, F1 = 16.24
# precision = 0.088, recall = 0.988
# Best F1 = 62.82 at thresh = 0.79

# %% [markdown]
# ## CMC dataset
# ### Download prediction result from the baseline git
#
# We used the prediction result of the detection stage of the CODAEL variant of the CMC dataset as an example.

# %%
# !wget -P ./ https://github.com/DeepPathology/MITOS_WSI_CMC/raw/master/results/test_RetinaNet-CMC-CODAEL-512sh-b1.pth-CODAEL-val-inference_results_boxes.p.bz2
# Out:
# --2022-07-18 11:43:43--  https://github.com/DeepPathology/MITOS_WSI_CMC/raw/master/results/test_RetinaNet-CMC-CODAEL-512sh-b1.pth-CODAEL-val-inference_results_boxes.p.bz2
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DeepPathology/MITOS_WSI_CMC/master/results/test_RetinaNet-CMC-CODAEL-512sh-b1.pth-CODAEL-val-inference_results_boxes.p.bz2 [following]
# --2022-07-18 11:43:44--  https://raw.githubusercontent.com/DeepPathology/MITOS_WSI_CMC/master/results/test_RetinaNet-CMC-CODAEL-512sh-b1.pth-CODAEL-val-inference_results_boxes.p.bz2
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 396507 (387K) [application/octet-stream]
# Saving to: ‘./test_RetinaNet-CMC-CODAEL-512sh-b1.pth-CODAEL-val-inference_results_boxes.p.bz2’
#
# test_RetinaNet-CMC- 100%[===================>] 387.21K  --.-KB/s    in 0.03s
#
# 2022-07-18 11:43:45 (11.2 MB/s) - ‘./test_RetinaNet-CMC-CODAEL-512sh-b1.pth-CODAEL-val-inference_results_boxes.p.bz2’ saved [396507/396507]

# %% [markdown]
# ### Decompress .p.bz2 file and format the output

# %%
import bz2
import pickle
import numpy as np

filepath = './test_RetinaNet-CMC-CODAEL-512sh-b1.pth-CODAEL-val-inference_results_boxes.p.bz2'
zipfile = bz2.BZ2File(filepath) # open the file
data = zipfile.read() # get the decompressed data
newfilepath = filepath[:-4] # assuming the filepath ends with .bz2
open(newfilepath, 'wb').write(data)
pred = pickle.load(open(newfilepath, 'rb'))
template = pickle.load(open('../detection/mmdetection/data/database/CMC_label.pkl', 'rb'))

for i in pred: 
    template[i]['pred_bbox'] = []
    bboxs = []
    for j in pred[i]:
        xmin, ymin, xmax, ymax, cls, conf = j
        bboxs.append(np.array([xmin, ymin, xmax, ymax, conf], dtype = np.float32))
    template[i]['pred_bbox'] = bboxs
pickle.dump(template, open('./CMC_baseline_git.pkl', 'wb'))

# %% [markdown]
# ### Evaluate the prediction result
#
# At the threshold of 0.62, the model achieves 0.726, 0.697, and 0.758 F1, precision, and recall, respectively. This match the result shown in https://github.com/DeepPathology/MITOS_WSI_CMC/blob/master/Evaluation.ipynb.

# %%
# !python3 tools/eval/calculate_F1.py -ip ./CMC_baseline_git.pkl
# Out:
# precision = 0.000, recall = 0.000
# precision = 0.000, recall = 0.000
# precision = 0.000, recall = 0.000
# precision = 0.000, recall = 0.000
# precision = 0.000, recall = 0.000
# precision = 0.000, recall = 0.000
# precision = 0.000, recall = 0.000
# precision = 0.000, recall = 0.000
# precision = 0.000, recall = 0.000
# precision = 0.000, recall = 0.000
# At thresh = 0.90 TP = 91, FN = 3321, FP = 0, F1 = 5.20
# precision = 1.000, recall = 0.027
# At thresh = 0.89 TP = 139, FN = 3273, FP = 1, F1 = 7.83
# precision = 0.993, recall = 0.041
# At thresh = 0.88 TP = 203, FN = 3209, FP = 1, F1 = 11.23
# precision = 0.995, recall = 0.059
# At thresh = 0.87 TP = 288, FN = 3124, FP = 3, F1 = 15.55
# precision = 0.990, recall = 0.084
# At thresh = 0.86 TP = 375, FN = 3037, FP = 7, F1 = 19.77
# precision = 0.982, recall = 0.110
# At thresh = 0.85 TP = 467, FN = 2945, FP = 11, F1 = 24.01
# precision = 0.977, recall = 0.137
# At thresh = 0.84 TP = 570, FN = 2842, FP = 13, F1 = 28.54
# precision = 0.978, recall = 0.167
# At thresh = 0.83 TP = 685, FN = 2727, FP = 19, F1 = 33.28
# precision = 0.973, recall = 0.201
# At thresh = 0.82 TP = 798, FN = 2614, FP = 32, F1 = 37.62
# precision = 0.961, recall = 0.234
# At thresh = 0.81 TP = 922, FN = 2490, FP = 45, F1 = 42.11
# precision = 0.953, recall = 0.270
# At thresh = 0.80 TP = 1044, FN = 2368, FP = 64, F1 = 46.19
# precision = 0.942, recall = 0.306
# At thresh = 0.79 TP = 1180, FN = 2232, FP = 82, F1 = 50.49
# precision = 0.935, recall = 0.346
# At thresh = 0.78 TP = 1295, FN = 2117, FP = 97, F1 = 53.91
# precision = 0.930, recall = 0.380
# At thresh = 0.77 TP = 1416, FN = 1996, FP = 111, F1 = 57.34
# precision = 0.927, recall = 0.415
# At thresh = 0.76 TP = 1516, FN = 1896, FP = 138, F1 = 59.85
# precision = 0.917, recall = 0.444
# At thresh = 0.75 TP = 1618, FN = 1794, FP = 166, F1 = 62.28
# precision = 0.907, recall = 0.474
# At thresh = 0.74 TP = 1712, FN = 1700, FP = 212, F1 = 64.17
# precision = 0.890, recall = 0.502
# At thresh = 0.73 TP = 1807, FN = 1605, FP = 256, F1 = 66.01
# precision = 0.876, recall = 0.530
# At thresh = 0.72 TP = 1895, FN = 1517, FP = 303, F1 = 67.56
# precision = 0.862, recall = 0.555
# At thresh = 0.71 TP = 1984, FN = 1428, FP = 360, F1 = 68.94
# precision = 0.846, recall = 0.581
# At thresh = 0.70 TP = 2061, FN = 1351, FP = 434, F1 = 69.78
# precision = 0.826, recall = 0.604
# At thresh = 0.69 TP = 2148, FN = 1264, FP = 496, F1 = 70.94
# precision = 0.812, recall = 0.630
# At thresh = 0.68 TP = 2228, FN = 1184, FP = 560, F1 = 71.87
# precision = 0.799, recall = 0.653
# At thresh = 0.67 TP = 2289, FN = 1123, FP = 624, F1 = 72.38
# precision = 0.786, recall = 0.671
# At thresh = 0.66 TP = 2342, FN = 1070, FP = 722, F1 = 72.33
# precision = 0.764, recall = 0.686
# At thresh = 0.65 TP = 2410, FN = 1002, FP = 801, F1 = 72.78
# precision = 0.751, recall = 0.706
# At thresh = 0.64 TP = 2477, FN = 935, FP = 895, F1 = 73.02
# precision = 0.735, recall = 0.726
# At thresh = 0.63 TP = 2536, FN = 876, FP = 995, F1 = 73.05
# precision = 0.718, recall = 0.743
# At thresh = 0.62 TP = 2586, FN = 826, FP = 1123, F1 = 72.63
# precision = 0.697, recall = 0.758
# At thresh = 0.61 TP = 2642, FN = 770, FP = 1238, F1 = 72.46
# precision = 0.681, recall = 0.774
# At thresh = 0.60 TP = 2687, FN = 725, FP = 1361, F1 = 72.04
# precision = 0.664, recall = 0.788
# At thresh = 0.59 TP = 2739, FN = 673, FP = 1480, F1 = 71.79
# precision = 0.649, recall = 0.803
# At thresh = 0.58 TP = 2786, FN = 626, FP = 1599, F1 = 71.46
# precision = 0.635, recall = 0.817
# At thresh = 0.57 TP = 2826, FN = 586, FP = 1763, F1 = 70.64
# precision = 0.616, recall = 0.828
# At thresh = 0.56 TP = 2863, FN = 549, FP = 1912, F1 = 69.94
# precision = 0.600, recall = 0.839
# At thresh = 0.55 TP = 2901, FN = 511, FP = 2067, F1 = 69.24
# precision = 0.584, recall = 0.850
# At thresh = 0.54 TP = 2939, FN = 473, FP = 2247, F1 = 68.36
# precision = 0.567, recall = 0.861
# At thresh = 0.53 TP = 2962, FN = 450, FP = 2428, F1 = 67.30
# precision = 0.550, recall = 0.868
# At thresh = 0.52 TP = 2989, FN = 423, FP = 2611, F1 = 66.33
# precision = 0.534, recall = 0.876
# At thresh = 0.51 TP = 3017, FN = 395, FP = 2802, F1 = 65.37
# precision = 0.518, recall = 0.884
# At thresh = 0.50 TP = 3040, FN = 372, FP = 2998, F1 = 64.34
# precision = 0.503, recall = 0.891
# At thresh = 0.49 TP = 3067, FN = 345, FP = 3213, F1 = 63.29
# precision = 0.488, recall = 0.899
# At thresh = 0.48 TP = 3089, FN = 323, FP = 3482, F1 = 61.89
# precision = 0.470, recall = 0.905
# At thresh = 0.47 TP = 3106, FN = 306, FP = 3733, F1 = 60.60
# precision = 0.454, recall = 0.910
# At thresh = 0.46 TP = 3120, FN = 292, FP = 3997, F1 = 59.26
# precision = 0.438, recall = 0.914
# At thresh = 0.45 TP = 3141, FN = 271, FP = 4249, F1 = 58.16
# precision = 0.425, recall = 0.921
# At thresh = 0.44 TP = 3157, FN = 255, FP = 4562, F1 = 56.72
# precision = 0.409, recall = 0.925
# At thresh = 0.43 TP = 3172, FN = 240, FP = 4848, F1 = 55.49
# precision = 0.396, recall = 0.930
# At thresh = 0.42 TP = 3190, FN = 222, FP = 5167, F1 = 54.21
# precision = 0.382, recall = 0.935
# At thresh = 0.41 TP = 3200, FN = 212, FP = 5509, F1 = 52.80
# precision = 0.367, recall = 0.938
# At thresh = 0.40 TP = 3213, FN = 199, FP = 5891, F1 = 51.34
# precision = 0.353, recall = 0.942
# At thresh = 0.39 TP = 3225, FN = 187, FP = 6259, F1 = 50.02
# precision = 0.340, recall = 0.945
# At thresh = 0.38 TP = 3240, FN = 172, FP = 6674, F1 = 48.63
# precision = 0.327, recall = 0.950
# At thresh = 0.37 TP = 3249, FN = 163, FP = 7048, F1 = 47.40
# precision = 0.316, recall = 0.952
# At thresh = 0.36 TP = 3258, FN = 154, FP = 7470, F1 = 46.08
# precision = 0.304, recall = 0.955
# At thresh = 0.35 TP = 3262, FN = 150, FP = 7938, F1 = 44.65
# precision = 0.291, recall = 0.956
# At thresh = 0.34 TP = 3267, FN = 145, FP = 8458, F1 = 43.17
# precision = 0.279, recall = 0.958
# At thresh = 0.33 TP = 3280, FN = 132, FP = 9003, F1 = 41.80
# precision = 0.267, recall = 0.961
# At thresh = 0.32 TP = 3291, FN = 121, FP = 9525, F1 = 40.56
# precision = 0.257, recall = 0.965
# At thresh = 0.31 TP = 3297, FN = 115, FP = 10128, F1 = 39.16
# precision = 0.246, recall = 0.966
# At thresh = 0.30 TP = 3308, FN = 104, FP = 10784, F1 = 37.80
# precision = 0.235, recall = 0.970
# At thresh = 0.29 TP = 3308, FN = 104, FP = 10784, F1 = 37.80
# precision = 0.235, recall = 0.970
# At thresh = 0.28 TP = 3308, FN = 104, FP = 10784, F1 = 37.80
# precision = 0.235, recall = 0.970
# At thresh = 0.27 TP = 3308, FN = 104, FP = 10784, F1 = 37.80
# precision = 0.235, recall = 0.970
# At thresh = 0.26 TP = 3308, FN = 104, FP = 10784, F1 = 37.80
# precision = 0.235, recall = 0.970
# At thresh = 0.25 TP = 3308, FN = 104, FP = 10784, F1 = 37.80
# precision = 0.235, recall = 0.970
# At thresh = 0.24 TP = 3308, FN = 104, FP = 10784, F1 = 37.80
# precision = 0.235, recall = 0.970
# At thresh = 0.23 TP = 3308, FN = 104, FP = 10784, F1 = 37.80
# precision = 0.235, recall = 0.970
# At thresh = 0.22 TP = 3308, FN = 104, FP = 10784, F1 = 37.80
# precision = 0.235, recall = 0.970
# At thresh = 0.21 TP = 3308, FN = 104, FP = 10784, F1 = 37.80
# precision = 0.235, recall = 0.970
# At thresh = 0.20 TP = 3308, FN = 104, FP = 10784, F1 = 37.80
# precision = 0.235, recall = 0.970
# At thresh = 0.19 TP = 3308, FN = 104, FP = 10784, F1 = 37.80
# precision = 0.235, recall = 0.970
# At thresh = 0.18 TP = 3308, FN = 104, FP = 10784, F1 = 37.80
# precision = 0.235, recall = 0.970
# At thresh = 0.17 TP = 3308, FN = 104, FP = 10784, F1 = 37.80
# precision = 0.235, recall = 0.970
# At thresh = 0.16 TP = 3308, FN = 104, FP = 10784, F1 = 37.80
# precision = 0.235, recall = 0.970
# At thresh = 0.15 TP = 3308, FN = 104, FP = 10784, F1 = 37.80
# precision = 0.235, recall = 0.970
# At thresh = 0.14 TP = 3308, FN = 104, FP = 10784, F1 = 37.80
# precision = 0.235, recall = 0.970
# At thresh = 0.13 TP = 3308, FN = 104, FP = 10784, F1 = 37.80
# precision = 0.235, recall = 0.970
# At thresh = 0.12 TP = 3308, FN = 104, FP = 10784, F1 = 37.80
# precision = 0.235, recall = 0.970
# At thresh = 0.11 TP = 3308, FN = 104, FP = 10784, F1 = 37.80
# precision = 0.235, recall = 0.970
# At thresh = 0.10 TP = 3308, FN = 104, FP = 10784, F1 = 37.80
# precision = 0.235, recall = 0.970
# At thresh = 0.09 TP = 3308, FN = 104, FP = 10784, F1 = 37.80
# precision = 0.235, recall = 0.970
# At thresh = 0.08 TP = 3308, FN = 104, FP = 10784, F1 = 37.80
# precision = 0.235, recall = 0.970
# At thresh = 0.07 TP = 3308, FN = 104, FP = 10784, F1 = 37.80
# precision = 0.235, recall = 0.970
# At thresh = 0.06 TP = 3308, FN = 104, FP = 10784, F1 = 37.80
# precision = 0.235, recall = 0.970
# Best F1 = 73.05 at thresh = 0.63
